# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Create a new directory Parallel

# %%
# !mkdir Parallel

# %%
# %cd Parallel
# Out:
# /content/Parallel/Image_Filtering_Serial/TVFilter/Parallel

# %% [markdown]
# Clone our github repo

# %%
# !git clone https://github.com/arihant-jain-09/Image_Filtering_Serial.git
# Out:
# Cloning into 'Image_Filtering_Serial'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 34 (delta 14), reused 34 (delta 14), pack-reused 0
# Unpacking objects: 100% (34/34), done.

# %%
# %cd Image_Filtering_Serial
# Out:
# /content/Parallel/Image_Filtering_Serial/TVFilter/Parallel/Image_Filtering_Serial

# %%
# !ls
# Out:
# BoxFilter	 MedianFilter	   SobelEdgeDetectFilter
# LaplacianFilter  SharpeningFilter  TVFilter

# %% [markdown]
# BoxFilter

# %%
# %cd BoxFilter
# Out:
# /content/Parallel/Image_Filtering_Serial/TVFilter/Parallel/Image_Filtering_Serial/BoxFilter

# %%
# input image
img = mpimg.imread('sample.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
# !g++ -o main main.cpp `pkg-config opencv --cflags --libs`

# %%
# !./main
# Out:
# input image size: 600 298 3
#
# Processing time for CPU (ms): 22.8439

# %%
img = mpimg.imread('sample_cpu.jpg')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# Laplacian Filter

# %%
# %cd ..
# Out:
# /content/Parallel/Image_Filtering_Serial/TVFilter/Parallel/Image_Filtering_Serial

# %%
# %cd LaplacianFilter
# Out:
# /content/Parallel/Image_Filtering_Serial/TVFilter/Parallel/Image_Filtering_Serial/LaplacianFilter

# %%
# !g++ -o main main.cpp `pkg-config opencv --cflags --libs`

# %%
# !./main
# Out:
# input image size: 600 298 3
#
# Processing time for CPU (ms): 0.622117

# %%
img = mpimg.imread('sample_cpu.jpg')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# Median Filter

# %%
# %cd ..
# Out:
# /content/Parallel/Image_Filtering_Serial/TVFilter/Parallel/Image_Filtering_Serial

# %%
# %cd MedianFilter/
# Out:
# /content/Parallel/Image_Filtering_Serial/TVFilter/Parallel/Image_Filtering_Serial/MedianFilter

# %%
# !g++ -o main main.cpp `pkg-config opencv --cflags --libs`

# %%
# !./main
# Out:
# input image size: 600 298 3
#
# Processing time on CPU (ms): 44.3656

# %%
img = mpimg.imread('sample_cpu.jpg')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# Sharpening Filter

# %%
# %cd ..
# Out:
# /content/Parallel/Image_Filtering_Serial/TVFilter/Parallel/Image_Filtering_Serial

# %%
# %cd SharpeningFilter/
# Out:
# /content/Parallel/Image_Filtering_Serial/TVFilter/Parallel/Image_Filtering_Serial/SharpeningFilter

# %%
# !ls
# Out:
# main  main.cpp	sample_cpu.jpg	sample.jpg  sharpeningFilter.cpp

# %%
# !g++ -o main main.cpp `pkg-config opencv --cflags --libs`

# %%
# !./main
# Out:
# input image size: 600 298 3
#
# Processing time on CPU (ms): 17.0203

# %%
img = mpimg.imread('sample_cpu.jpg')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# SobelEdgeDetectFilter

# %%
# %cd ..
# Out:
# /content/Parallel/Image_Filtering_Serial/TVFilter/Parallel/Image_Filtering_Serial

# %%
# %cd SobelEdgeDetectFilter/
# Out:
# /content/Parallel/Image_Filtering_Serial/TVFilter/Parallel/Image_Filtering_Serial/SobelEdgeDetectFilter

# %%
# !ls
# Out:
# main  main.cpp	sample_cpu.jpg	sample.jpg  sobelEdgeDetectionFilter.cpp

# %%
# !g++ -o main main.cpp `pkg-config opencv --cflags --libs`

# %%
# !./main
# Out:
# input image size: 600 298 3
#
# Processing time on CPU (ms): 1.23031

# %%
img = mpimg.imread('sample_cpu.jpg')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# TVFilter

# %%
# %cd ..
# Out:
# /content/Parallel/Image_Filtering_Serial/TVFilter/Parallel/Image_Filtering_Serial

# %%
# %cd TVFilter/
# Out:
# /content/Parallel/Image_Filtering_Serial/TVFilter/Parallel/Image_Filtering_Serial/TVFilter

# %%
# !ls
# Out:
# main  main.cpp	sample_cpu.jpg	sample.jpg  tvFilter.cpp

# %%
# !g++ -o main main.cpp `pkg-config opencv --cflags --libs`

# %%
# !./main
# Out:
# input image size: 600 298 3
#
# Processing time on CPU (ms): 1.30586

# %%
img = mpimg.imread('sample_cpu.jpg')
imgplot = plt.imshow(img)
plt.show()
